# %%
from IPython.display import Image
#getting all the libraries from qiskit
from qiskit import *

#some qiskit visualization libs
from qiskit.visualization import plot_histogram, circuit_drawer, plot_bloch_multivector, plot_state_city

#the essential libraries
import numpy as np
import time 
import matplotlib.pyplot as plt
import random
import seaborn as sb #just for a better visualization sometimes i might use it.

#for running on a realdevice and linking a ibm id
from qiskit import IBMQ, Aer, execute

# %%
provider = IBMQ.load_account()

# %%
available_cloud_backends = provider.backends() 
print('\nHere is the list of cloud backends that are available to you:')
for i in available_cloud_backends: print(i)
# Out:
# Here is the list of cloud backends that are available to you:
# ibmq_qasm_simulator
# ibmq_lima
# ibmq_belem
# ibmq_quito
# simulator_statevector
# simulator_mps
# simulator_extended_stabilizer
# simulator_stabilizer
# ibmq_manila
# ibm_nairobi
# ibm_oslo

# %% [markdown]
# ## I found this while looking for something on stack exchange, here is the link its just shows the circuit, i used qiskit textbook to implement see it. LINK: (https://cstheory.stackexchange.com/questions/38538/oracle-construction-for-grovers-algorithm)

# %% [markdown]
# ## Basic Overview of the algorithm

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Tips for oracle building, I'm solving this get myself some hang of oracle constructions, so the oracle is basically just an implementation of the predicate you want to search for a satisfying solution to.

# %% [markdown]
# ## Describing a Basic MAX-SAT (Maximium Satisfibilty) Problem

# %% [markdown]
# ## The maximum satisfiability problem (MAX-SAT) is the problem of determining the maximum number of clauses, of a given Boolean formula in conjunctive normal form, that can be made true by an assignment of truth values to the variables of the formula. (totallly from wikipedia, easy to make sense)

# %% [markdown]
# # EG: 1 (this is a unweighted case)

# %% [markdown]
# # 3 - SAT w 5 clauses
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### x1 =  litreal 1
# ### x2 =  litreal 2
# ### x3 =  litreal 3
# ### x4 =  litreal 4
# ### ~x1 =  negate litreal 1
# ### ~x2 =  negate litreal 2
# ### ~x3 =  negate litreal 3
# ### ~x4 =  negate litreal 4

# %% [raw]
#    0     |  1        2        3        4
# clause(s)|
#    1     |  N                 N        N
#    2     |            P       P        N
#    3     |  P         N                P
#    4     |  P                 P        P
#    5     |  N                 N        N

# %% [markdown]
# ## Oracle Ideation:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Grover's Algorithm for MAX - 3 - SAT

# %% [markdown]
# ## Intialize the circuit

# %%
#initialzing the ancillary and main registers 

qreg_q = QuantumRegister(9, 'q')
creg_c = ClassicalRegister(2, 'c')
circuit = QuantumCircuit(qreg_q, creg_c)

def initialize(circuit):
    circuit.h(qreg_q[0])
    circuit.h(qreg_q[1])
    circuit.h(qreg_q[2])
    circuit.h(qreg_q[3])
    circuit.h(qreg_q[4])
    circuit.h(qreg_q[5])
    circuit.h(qreg_q[6])
    circuit.h(qreg_q[7])
    circuit.h(qreg_q[8])
    circuit.barrier(qreg_q[0], qreg_q[1], qreg_q[2],  qreg_q[3], qreg_q[4], qreg_q[5], qreg_q[6], qreg_q[7], qreg_q[8])
    return circuit
    
initialize(circuit)
circuit.draw('mpl')

# %% [markdown]
# ## Implementing the Oracle:

# %%
def oracle(circuit):
# Out:
#   File "C:\Users\ANANTS~1\AppData\Local\Temp/ipykernel_23272/2708848394.py", line 1
#     def oracle(circuit)
#                        ^
# SyntaxError: invalid syntax
